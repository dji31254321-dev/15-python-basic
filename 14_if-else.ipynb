# %%
# else 사용하기
x = 5
if x == 10: print("10입니다.")
else: print("10이 아닙니다.")
# Out:
# 10이 아닙니다.

# %%
x = 5
if x == 10:
    print("10입니다.")
else:
    print("x에 들어있는 숫자는")
    print("10이 아닙니다.")
# Out:
# x에 들어있는 숫자는
# 10이 아닙니다.

# %%
# if 조건문의 동작 방식 알아보기
if True:
    print("참")
else:
    print("거짓")
# Out:
# 참

# %%
if False:
    print("참")
else:
    print("거짓")
# Out:
# 거짓

# %%
if None:
    print("참")
else:
    print("거짓")

bool(None)
# Out:
# 거짓
# False

# %%
if 0:
    print("참")
else:
    print("거짓")
# Out:
# 거짓

# %%
if 1:
    print("참")
else:
    print("거짓")
# Out:
# 참

# %%
if []:
    print("참")
else:
    print("거짓")
# Out:
# 거짓

# %%
x = 10
y = 20
if x == 10 and y == 20:
    print("참")
else:
    print("거짓")
# Out:
# 참

# %%
# 10이상이고 20미만인 숫자는 참
x = int(input("숫자를 입력하세요: "))

if x >= 10 and x <=20:
    print("참")
else:
    print("거짓")
# Out:
# 참

# %%
written_test = 75
coding_test = True
if written_test >= 80 and coding_test == True:
    print("합격")
else:
    print("불합격")
# Out:
# 불합격

# %%
국 = int(input(""))
영 = int(input(""))
수 = int(input(""))
과 = int(input(""))
if 국 >100 or 영 >100 or 수>100 or 과>100:
    print("잘못된 점수")
else:
    if (국+영+수+과)/4 >=80:
        print("합격")
    else:
        print("불합격")
# Out:
# 합격
