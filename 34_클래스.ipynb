# %%
# 클래스와 매서드 만들기
# class 클래스이름:
#     def 매서드(self):
#         코드
class Person:
    def greeting(self):
        print("Hello")
# 인스턴스 = 클래스
james = Person()

# %%
james.greeting()
# Out:
# Hello

# %%
a = int(10)
b = list(range(10))
print(type(a))
# Out:
# <class 'int'>

# %%
# # 속성 사용하기
# class 클래스이름:
#     def __init__(self):
#         self.속성 = 값

class Person:
    def __init__(self):
        self.hello = "안녕하세요"
        
    def greeting(self):
        print("Hello")

# %%
james = Person()
james.hello
# Out:
# '안녕하세요'

# %%
class Person:
    def __init__(self):
        self.hello = "안녕하세요"
        
    def greeting(self):
        print(self.hello)
jane = Person()
jane.greeting()
# Out:
# 안녕하세요

# %%
# 인스턴스를 만들 때 값 받기
# class 클래스이름:
#     def __init__(self, 매개변수1, 매개변수2):
#         self.속성1 = 매개변수1
#         self.속성2 = 매개변수2

class Person:
    def __init__(self, name, age, address):
        self.hello = "안녕하세요"
        self.name = name
        self.age = age
        self.address = address
    def greeting(self):
        print(f"{self.hello} 저는 {self.name}입니다. ")
maria = Person("마리아", 20, "서울시 서초구 반포동")
maria.greeting()
# Out:
# 안녕하세요 저는 마리아입니다.

# %%
print("이름: ", maria.name)
print("나이: ", maria.age)
print("주소: ", maria.address)
# Out:
# 이름:  마리아
# 나이:  20
# 주소:  서울시 서초구 반포동

# %%
# 비공개 속성 사용하기
# 인스턴스를 만들 때 값 받기
# class 클래스이름:
#     def __init__(self, 매개변수1):
#         self.속성1 = 매개변수1
#         self.__속성2 = 값
class Person:
    def __init__(self, name, age, address, wallet):
        self.hello = "안녕하세요"
        self.name = name
        self.age = age
        self.address = address
        self.__wallet = wallet # 비공개 속성(__)
maria = Person("마리아", 20, "서울시 서초구 반포동", 10000)
maria.__wallet
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 15
#      11         self.age = age
#      12         self.address = address
#      13         self.__wallet = wallet # 비공개 속성(__)
#      14 maria = Person("마리아", 20, "서울시 서초구 반포동", 10000)
# ---> 15 maria.__wallet
#
# AttributeError: 'Person' object has no attribute '__wallet'

# %%
class Person:
    def __init__(self, name, age, address, wallet):
        self.hello = "안녕하세요"
        self.name = name
        self.age = age
        self.address = address
        self.__wallet = wallet # 비공개 속성(__)
    def pay(self, amount):
        self.__wallet -= amount
        print(f"이제 {self.__wallet}이 남았습니다")
    
maria = Person("마리아", 20, "서울시 서초구 반포동", 10000)
maria.pay(3000)
# Out:
# 이제 7000이 남았습니다

# %%
class Person:
    def __init__(self, name, age, address, wallet):
        self.hello = "안녕하세요"
        self.name = name
        self.age = age
        self.address = address
        self.__wallet = wallet # 비공개 속성(__)
    def pay(self, amount):
        if amount > self.__wallet:
            print("돈이 모자라네")
            return 
        self.__wallet -= amount
        print(f"이제 {self.__wallet}이 남았습니다")
    
maria = Person("마리아", 20, "서울시 서초구 반포동", 10000)
maria.pay(3000)
maria.pay(20000)
# Out:
# 이제 7000이 남았습니다
# 돈이 모자라네

# %%
class Knights:
    def __init__(self, health, mana, armor):
        self.health = health
        self.mana = mana
        self.armor = armor
    def slash(self):
        print("베기")

x = Knights(health = 542, mana = 210, armor = 38)
print(x.health, x.mana, x.armor)
x.slash()
# Out:
# 542 210 38
# 베기

# %%
class Annie:
    def __init__(self, health, mana, ability_power):
        self.health = health
        self.mana = mana
        self.ability_power = ability_power
    def tibbers(self):
        a = self.ability_power * 0.65 + 400
        print(f"티버: 피해량 {a}")
health, mana, ability_power = map(float, input().split())
x = Annie(health = health, mana = mana, ability_power = ability_power)
x.tibbers()
# Out:
# 티버: 피해량 819.25
