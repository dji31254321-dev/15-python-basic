# %%
# 불과 비교 연산자 사용하기
True
False

# %%
# 비교연산자의 판단 결과

3 > 1
# Out:
# True

# %%
# 숫자 같은지 비교
10 == 10
# Out:
# True

# %%
print("Python"=="Python")
print("Python"=="python")
print("Python"!="python")
# Out:
# True
# False
# True

# %%
# 부등호 사용하기
print(10 > 20)
print(10 < 20)
print(10 >= 10)
print(10 <= 10)
# Out:
# False
# True
# True
# True

# %%
# 객체가 같은지 다른지 비교하기
print(1 == 1.0)
print(1 is 1.0)
# Out:
# True
# False
# <>:3: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# <>:3: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# C:\Users\Win11Pro\AppData\Local\Temp\ipykernel_12588\3348409661.py:3: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
#   print(1 is 1.0)

# %%
not True
# Out:
# False

# %%
not False
# Out:
# True

# %%
1 is not 1.0
# Out:
# <>:1: SyntaxWarning: "is not" with 'int' literal. Did you mean "!="?
# <>:1: SyntaxWarning: "is not" with 'int' literal. Did you mean "!="?
# C:\Users\Win11Pro\AppData\Local\Temp\ipykernel_12588\2095918375.py:1: SyntaxWarning: "is not" with 'int' literal. Did you mean "!="?
#   1 is not 1.0
# True

# %%
# 논리 연산자 사용하기
## AND
print(True and True)
print(True and False)
print(False and True)
print(False and False)
# Out:
# True
# False
# False
# False

# %%
# OR
print(True or True)
print(True or False)
print(False or True)
print(False or False)
# Out:
# True
# True
# True
# False
