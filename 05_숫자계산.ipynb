# %%
# 사칙연산
print(1+1)
1-1
print(2 * 2)
print(4 / 2)
# Out:
# 2
# 4
# 2.0

# %%
# 나눗셈 후 소수점 이하를 버리는 // 연산자(몫)
5 // 2
# Out:
# 2

# %%
# % 연산자(나머지를 구하는 연산자)
5 % 2
# Out:
# 1

# %%
# ** (거듭제곱을 구하는 연산자)
2 ** 10

# 제곱근
4 ** 0.5
# Out:
# 2.0

# %%
# 값을 정수로 만들기 
int(3.3)
int(4/2)
# Out:
# 2

# %%
# 객체의 자료형 알아내기(type)
type(10)
# Out:
# int

# %%
# 2진수
print(0b110)
(1 * 2**2) + (1 * 2**1) + (0 * 2**0)
# Out:
# 6
# 6

# %%
# 8진수
print(0o110)
(1 * 8**2) + (1 * 8**1) + (0 * 8**0)
# Out:
# 72
# 72

# %%
# 16진수
print(0xAF)
(10 * 16**1) + (15 * 16**0)
# Out:
# 175
# 175

# %%
# 실수 계산하기
3.5 + 2.1
# Out:
# 5.6

# %%
4.2 + 5
# Out:
# 9.2

# %%
# 값을 실수로 만들기()
float(5)
float()
float("5.3") # -> 문자열
# Out:
# 5.3

# %%
# 괄호 사용하기
print(2+2*2)
print((2+2)*2)
# Out:
# 6
# 8
