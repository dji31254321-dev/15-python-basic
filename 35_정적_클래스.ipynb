# %%
# 클래스 속성 사용하기
# class 클래스이름:
#     속성 = 값
class Person:
    bag = []
    def put_bag(self, stuff):
        Person.bag.append(stuff)

james = Person()
james.put_bag("책")

maria = Person()
maria.put_bag("열쇠")
print(james.bag)
print(maria.bag)
# Out:
# ['책', '열쇠']
# ['책', '열쇠']

# %%
print(Person.bag)
# Out:
# ['책', '열쇠']

# %%
# 인스턴스 속성 사용하기
class Person:
    # bag = []

    def __init__(self):
        self.bag = []

    def put_bag(self, stuff):
        self.bag.append(stuff)

james = Person()
james.put_bag("책")

maria = Person()
maria.put_bag("열쇠")
print(james.bag)
print(maria.bag)
# Out:
# ['책']
# ['열쇠']

# %%
# 비공개 클래스 속성 사용하기
## class 클래스이름:
##     __속성 = 값

class Knight:
    __item_limit = 10

    def print_item_limit(self):
        print(Knight.__item_limit)
x = Knight()
x.print_item_limit()

print(Knight.item_limit())
# Out:
# 10
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 13
#       9         print(Knight.__item_limit)
#      10 x = Knight()
#      11 x.print_item_limit()
#      12
# ---> 13 print(Knight.item_limit())
#
# AttributeError: type object 'Knight' has no attribute 'item_limit'

# %%
# 정적 매서드 사용하기

# class 클래스이름:
#     @staticmethod
#     def 매서드(매개변수):
#         코드

class Calc:
    @staticmethod
    def add(a, b):
        return a + b
    @staticmethod
    def mul(a, b):
        return a * b

print(Calc.add(10, 20))
print(Calc.mul(10, 20))
# Out:
# 30
# 200

# %%
# 클래스 매서드 사용하기
# class 클래스이름:
#     @classmethod
#     def 매서드(cls, 매개변수1, 매개변수2):
#         코드

class Person:
    count = 0
    def __init__(self):
        Person.count += 1
    
    @classmethod
    def print_count(cls):
        print(f"{cls.count}명 생성되었습니다.")

james = Person()
maria = Person()
Person.print_count()
# Out:
# 2명 생성되었습니다.
