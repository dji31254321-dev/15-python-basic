# %%
# 딕셔너리 만들기
lux = {
    "health":490, 
    "mana":334,
    "melee":550,
    "armor":18.72
}
print(type(lux))
print(lux)
# Out:
# <class 'dict'>
# {'health': 490, 'mana': 334, 'melee': 550, 'armor': 18.72}

# %%
# 키 이름이 중복이 되면?
lux = {
    "health":490, 
    "health":800,
    "mana":334,
    "melee":550,
    "armor":18.72
}
print(lux)
print(lux["health"])
# Out:
# {'health': 800, 'mana': 334, 'melee': 550, 'armor': 18.72}
# 800

# %%
# 딕셔너리 키의 자료형
## 1. 문자형 가능
## 2. 정수형 가능
## 3. 실수형 가능
## 4. 불(True, False) 가능

## 불가능한 키의 자료형
## 1. 딕셔너리 불가능
## 2. 리스트 불가능

# %%
x = {
    100:"hundred",
    False:0,
    3.5:[3.5, 3.5],

}

print(type(x))
print(x)
# Out:
# <class 'dict'>
# {100: 'hundred', False: 0, 3.5: [3.5, 3.5]}

# %%
y = {
    [10,20]:100,

}
print(y)
print(type(y))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 y = {
#       2     [10,20]:100,
#       3
#       4 }
#
# TypeError: cannot use 'list' as a dict key (unhashable type: 'list')

# %%
z = {
    {"a":10}:100
}
print(z)
pritn(type(z))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 z = {
#       2     {"a":10}:100
#       3 }
#       4 print(z)
#
# TypeError: cannot use 'dict' as a dict key (unhashable type: 'dict')

# %%
# 빈 딕셔너리 만들기
x = {}
y = dict()
print(x)
print(type(x))
print(bool(x))
print(y)
print(type(y))
print(bool(y))
# Out:
# {}
# <class 'dict'>
# False
# {}
# <class 'dict'>
# False

# %%
# dict로 딕셔너리 만들기
lux1 = dict(health=400, mana=334, melee=550, armor=10.72)
print(lux1)
print(type(lux1))
# Out:
# {'health': 400, 'mana': 334, 'melee': 550, 'armor': 10.72}
# <class 'dict'>

# %%
lux2 = dict(zip(["health","mana","melee","armor"], [490, 334, 550, 10.72]))
print(lux2)
print(type(lux2))
# Out:
# {'health': 490, 'mana': 334, 'melee': 550, 'armor': 10.72}
# <class 'dict'>

# %%
lux3 = dict([("health", 490), ("mana", 334), ("melee", 550), ("armor", 10.72)])
print(lux3)
print(type(lux3))
# Out:
# {'health': 490, 'mana': 334, 'melee': 550, 'armor': 10.72}
# <class 'dict'>

# %%
# 딕셔너리의 키에 값 할당하기
lux = {
    "health":490, 
    "mana":334,
    "melee":550,
    "armor":18.72
}

lux["health"]
lux["armor"]
# Out:
# 18.72

# %%
lux["health"]=2037
print(lux)
# Out:
# {'health': 2037, 'mana': 334, 'melee': 550, 'armor': 18.72}

# %%
lux["mana_regen"] = 3.28
print(lux)
# Out:
# {'health': 2037, 'mana': 334, 'melee': 550, 'armor': 18.72, 'mana_regen': 3.28}

# %%
lux["attack_speed"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 lux["attack_speed"]
#
# KeyError: 'attack_speed'

# %%
# 딕셔너리에 키가 있는지 확인하기
"health" in lux
"attack_speed" in lux
# Out:
# False

# %%
# 딕셔너리 키의 개수 구하기
print(lux)
# Out:
# {'health': 2037, 'mana': 334, 'melee': 550, 'armor': 18.72, 'mana_regen': 3.28}

# %%
len(lux)
# Out:
# 5

# %%
camile = {
    'health':575.6,
    'health_regen':1.7,
    'mana':338.8,
    'mana_regen':1.63,
    'melee':125,
    'attack_damage':60,
    'attack_speed':0.625,
    'armor':26,
    'magic_resistance':32.1,
    'movement_speed':340
}
print(camile['health'])
print(camile['movement_speed'])
# Out:
# 575.6
# 340

# %%
ability_name = input().split()
ability = input().split()
ability_dict = dict(zip(ability_name, ability))

print(ability_dict)
# Out:
# {}

# %%
# Out:
# 10입니다

# %%
x = 5
if x != 10:
    print("ok")
# Out:
# ok

# %%
a = int(input("가격: "))
b = input("쿠폰: ")

if b == "Cash5000":
    cash=a-5000
elif b == "Cash3000":
    cash=a-3000
print(cash)
# Out:
# 22000
