# %%
x = 10
if x == 10:
    print("10입니다")
# Out:
# 10입니다

# %%
x = 10
if x == 10:
    print("x에 들어있는 숫자는")
    print("10입니다")
# Out:
# x에 들어있는 숫자는
# 10입니다

# %%
x = 10
if x == 10:
    print("x에 들어있는 숫자는")
print("10입니다")
# Out:
# x에 들어있는 숫자는
# 10입니다

# %%
# 중첩 if 조건문 사용하기
#x = 15
x = 10
if x >= 10:
    print("10이상입니다")
    if x == 10:
        print("10입니다")

    if x==20:
        print("20입니다")
# Out:
# 10이상입니다
# 10입니다

# %%
x = int(input("숫자를 입력하세요"))
if x == 10:
    print("10입니다")
if x == 20:
    print("20입니다")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 x = int(input("숫자를 입력하세요"))
#       2 if x == 10:
#       3     print("10입니다")
#       4 if x == 20:
#
# ValueError: invalid literal for int() with base 10: ''

# %%
x = 5
if x != 10:
    print("ok")
# Out:
# ok

# %%
a = int(input("가격: "))
b = input("쿠폰: ")

if b == "Cash5000":
    cash=a-5000
elif b == "Cash3000":
    cash=a-3000
print(cash)
# Out:
# 17000
