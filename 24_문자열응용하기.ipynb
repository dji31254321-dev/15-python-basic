# %%
# 문자열 바꾸기
"Hello, world!".replace("world", "Python")
# Out:
# 'Hello, Python!'

# %%
s = "Hello, world!"
s = s.replace("world","Python")
print(s)
# Out:
# Hello, Python!

# %%
a = [1, 2, 3, 4]
a.append(5)
print(a)
a = "hello"
a = "hi"
print(a)
# Out:
# [1, 2, 3, 4, 5]
# hi

# %%
# # 문자 바꾸기
table = str.maketrans("aeiou", "12345")
# table = "".maketrans("aeiou", "12345")
"apple".translate(table)
# Out:
# '1ppl2'

# %%
# 문자열 분리하기
"apple pear grape pineapple orange".split()
# Out:
# ['apple', 'pear', 'grape', 'pineapple', 'orange']

# %%
"apple,pear,grape,pineapple,orange".split(",")
# Out:
# ['apple', 'pear', 'grape', 'pineapple', 'orange']

# %%
# 구분자 문자열과 문자열 리스트 연결하기
" ".join(['apple', 'pear', 'grape', 'pineapple', 'orange'])
# Out:
# 'apple pear grape pineapple orange'

# %%
"-".join(['apple', 'pear', 'grape', 'pineapple', 'orange'])
# Out:
# 'apple-pear-grape-pineapple-orange'

# %%
# 소문자를 대문자로 바꾸기
"python".upper()
# Out:
# 'PYTHON'

# %%
# 대문자를 소문자로 바꾸기
"PYTHON".lower()
# Out:
# 'PYTHON'

# %%
# 왼쪽 공백 삭제하기
"   python  ".lstrip()
# Out:
# 'python  '

# %%
# 오른쪽 공백 삭제하기
"   python  ".rstrip()
# Out:
# '   python'

# %%
# 양쪽 공백 삭제하기
"   python  ".strip()
# Out:
# 'python'

# %%
# 양쪽의 특정 문자 삭제하기
",. python .,".strip("., ")
# Out:
# 'python'

# %%
# 문자열을 왼쪽 정렬하기
"python".ljust(10)
# Out:
# 'python    '

# %%
"python".rjust(10)
# Out:
# '    python'

# %%
# 문자열을 가운데 정렬하기
"python".center(10)
# Out:
# '  python  '

# %%
"python".center(11)
# Out:
# '   python  '

# %%
# 문자열 왼쪽에 0채우기
print("35".zfill(4))
print("3.5".zfill(6))
print("hello".zfill(10))
# Out:
# 0035
# 0003.5
# 00000hello

# %%
# 문자열 위치 찾기
"apple pineapple".find("ple")
# Out:
# 2

# %%
"apple pineapple".find("xy")
# Out:
# -1

# %%
# 오른쪽에서부터 문자열 찾기
"apple pineapple".rfind("pl")
# Out:
# 12

# %%
# 문자열 위치 찾기(index)
"apple pineapple".index("pl")
# Out:
# 2

# %%
# 문자열 개수 세기
"apple pineapple".count("pl")
# Out:
# 2

# %%
# 문자열 서식 지정자와 포맷팅 사용하기
# "%s"%"문자열"
"I am %s" % "james"
# Out:
# 'I am james'

# %%
name = "maria"
"I am %s" % name
# Out:
# 'I am maria'

# %%
# 서식 지정자로 숫자 넣기
# "%d" % 숫자
"I am %d years old" % 20
# Out:
# 'I am 20 years old'

# %%
# 서식 지정자로 소수점 표현하기
"%f" % 2.3
# Out:
# '2.300000'

# %%
print("%.2f" % 2.3)
print("%.3f" % 2.3)
# Out:
# 2.30
# 2.300

# %%
# 서식 지정자로 문자열 정렬
print("%10s" % "python")
print("%-10s" % "python")
# Out:
#     python
# python

# %%
# 서식 지정자로 문자열 안에 값 여러 개 넣기
"Today is %d %s" % (3, "april")
# Out:
# 'Today is 3 april'

# %%
# format 매서드 사용하기
print("Hello, {0}".format("world"))
print("Hello, {0}".format(100))
# Out:
# Hello, world
# Hello, 100

# %%
"Hello {0} {2} {1}".format("python", "script", 3.6)
# Out:
# 'Hello python 3.6 script'

# %%
"Hello {} {} {}".format("python", "script", 3.6)
# Out:
# 'Hello python script 3.6'

# %%
"Hello {language} {version}".format(language="python", version=3.6)
# Out:
# 'Hello python 3.6'

# %%
language = "Python"
version = 3.6

f"Hello, {language} {version}"
# Out:
# 'Hello, Python 3.6'

# %%
# format 매서드로 문자열 정렬하기
print("{0:<10}".format("python"))
print("{0:>10}".format("python"))
# Out:
# python
#     python

# %%
# 숫자 개수 맞추기
"%03d" % 1
# Out:
# '001'

# %%
"{:03d}".format(35)
# Out:
# '035'

# %%
print("%f" % 3.6)
print("%8.2f" % 3.6)
print("%08.2f" % 3.6)
# Out:
# 3.600000
#     3.60
# 00003.60

# %%
a = 12345.98765
print(f"{a:12,.2f}")
# Out:
#    12,345.99

# %%
path = 'C:\\Users\\dojang\\AppData\\Local\\Programs\\Python\\Python36-32\\Python.exe'
x = path.split("\\")
filename=x[-1]
print(filename)
# Out:
# Python.exe

# %%
"'the grown-ups' response, this time, was to advise me to lay aside my drawings of boa constrictors, whether from the inside or the outside, and devote my self instead to " \
"geography, history, arithmetic, and grammer. That is why, at the, age of six, I gave up what might have been a magnificent career as a painter. I had been disheartened by the failure" \
"of my Drawing Number One and my Drawing Number Two. Grown-ups never understand anything by themselves, and it is tiresome for children to be always and forever explaining things to the." 

a = input().split()
count = 0
for i in a:
    b = i.strip("',. ")
    if b == "the":
        count += 1
print(count)
# Out:
# 6

# %%
price = list(map(int,input().split(";")))
price.sort(reverse=True)
for i in price:
    print(f"{i:>9,}")
# Out:
# 1,304,000
#   367,500
#   250,000
#   158,000
#   128,500
#    83,000
#    59,200
#    51,900
