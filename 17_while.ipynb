# %%
# while 조건문:
#     반복할 코드
i = 0
while i < 100:
    print("hello world")
    i += 1
# Out:
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# ...

# %%
# 초기값을 1부터 시작하기
i = 1
while i <= 100:
    print("hello world")
    i += 1
# Out:
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# ...

# %%
# 초기값을 감소시키기
i = 100
while i > 0:
    print("hello world", i)
    i -= 1
# Out:
# hello world 100
# hello world 99
# hello world 98
# hello world 97
# hello world 96
# hello world 95
# hello world 94
# hello world 93
# hello world 92
# hello world 91
# hello world 90
# hello world 89
# hello world 88
# hello world 87
# hello world 86
# hello world 85
# hello world 84
# hello world 83
# hello world 82
# hello world 81
# hello world 80
# hello world 79
# hello world 78
# hello world 77
# hello world 76
# hello world 75
# hello world 74
# hello world 73
# hello world 72
# hello world 71
# hello world 70
# hello world 69
# hello world 68
# hello world 67
# hello world 66
# hello world 65
# hello world 64
# hello world 63
# hello world 62
# hello world 61
# hello world 60
# hello world 59
# hello world 58
# hello world 57
# hello world 56
# hello world 55
# hello world 54
# hello world 53
# hello world 52
# hello world 51
# hello world 50
# hello world 49
# hello world 48
# hello world 47
# hello world 46
# hello world 45
# hello world 44
# hello world 43
# ...

# %%
# 입력한 횟수대로 반복하기
count = int(input("반복할 횟수를 입력하세요: "))
i = 0
while i < count:
    print("hello world", i)
    i += 1
# Out:
# hello world 0
# hello world 1
# hello world 2
# hello world 3
# hello world 4

# %%
import random
random.random()
# Out:
# 0.05984147032550058

# %%
random.randint(1, 10)
# Out:
# 7

# %%
import random
i = 0
while i != 3:
    i = random.randint(1, 6)
    print(i)
# Out:
# 2
# 4
# 5
# 5
# 2
# 1
# 2
# 2
# 2
# 1
# 2
# 6
# 1
# 6
# 6
# 4
# 5
# 6
# 3

# %%
i = 2
j = 5
while i <= 32 or j >=1:
    print(i, j)
    i *= 2
    j -= 1
# Out:
# 2 5
# 4 4
# 8 3
# 16 2
# 32 1

# %%
card = int(input())
i = 0
while card-i >= 0:
    print(card - i)
    i += 1350
# Out:
# 10000
# 8650
# 7300
# 5950
# 4600
# 3250
# 1900
# 550
